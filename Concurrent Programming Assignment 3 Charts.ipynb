# %%
# Segments
from matplotlib import pyplot as plt
import numpy as np
segment_vals = [2043913.5, 3547138.3, 5676614.2, 8776690.7, 1.21473346E7, 1.35142772E7]
segment_labels = ["", "1", "2", "4", "8", "16", "32"]
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(segment_vals, label="Segmented", color="green")
ax.set_xticklabels(segment_labels)
ax.set_yticklabels(ax.get_yticks())
plt.xlabel("Segments")
plt.ylabel("Average Operations per Second")
plt.legend()
plt.show()

# %%
# Threads
thread_labels = ["", "1", "2", "4", "8", "16", "32"]
coarse_grain_threads = [5832958.0, 3827988.5, 2229290.3, 2091458.0, 1369353.4, 1508308.7]
segmented_threads = [5394607.2, 8424117.2, 1.0640397E7, 8739823.7, 6882588.6, 7470542.1]
lockfree_threads = [2183046.4, 5487181.6, 1.0385722E7, 1.69730857E7, 1.50987692E7, 1.44793643E7]

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(coarse_grain_threads, label="Coarse Grain", color="red")
ax.plot(segmented_threads, label="Segmented", color="green")
ax.plot(lockfree_threads, label="Lock-free", color="blue")

ax.set_xticklabels(thread_labels)
ax.set_yticklabels(ax.get_yticks())
ax.legend()

plt.xlabel("Threads")
plt.ylabel("Average Operations per Second")
plt.show()

# %%
# Get Operation %
get_op_label = ['', '33%', '50%', '66%', '75%', '90%', '99%']
coarse_grain_get = [3699910.5, 3878155.0, 6535880.2, 7122859.9, 4384870.1, 4224079.9]
segemented_get = [8765508.2, 9000305.2, 9317511.6, 9916279.9, 1.07617957E7, 1.1199262E7]
lockfree_get = [6473099.0, 8064185.6, 1.09377975E7, 1.29667624E7, 1.55624132E7, 2.1002802E7]

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(coarse_grain_get, label="Coarse Grain", color="red")
ax.plot(segemented_get, label="Segmented", color="green")
ax.plot(lockfree_get, label="Lock-free", color="blue")

ax.set_xticklabels(get_op_label)
ax.set_yticklabels(ax.get_yticks())
ax.legend()

plt.xlabel("Get Operations %")
plt.ylabel("Average Operations per Second")
plt.show()
